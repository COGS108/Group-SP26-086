# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# Member 1: Ethan Choi: Analysis, Project Administration, Writing - complete rough draft
#
# Member 2: Peerless Dang: Analysis, Project administration, Writing – original draft
#
# Member 3: TonyHaoran Huang
#
# Member 4: Joey Kim
#
# Member 5  Donovan Ho

# %% [markdown]
# ## Research Question

# %% [markdown]
# Does the diversity of the professional Overwatch 2 meta, measured by hero pick rate entropy across Overwatch Champions Series (OWCS) tournaments, correlate with changes in the game's monthly active player count? Specifically, we ask: do seasons with lower hero concentration (more diverse pro picks) show significantly higher or faster-growing player counts compared to seasons with a dominant, homogeneous meta?
# Our predictor variable is pro meta diversity per season (quantified using Shannon entropy applied to hero pick rate distributions from OWCS match data). Our outcome variable is monthly active player estimates, sourced from third-party trackers using ActivePlayer.io aggregated cross-platform data, aligned by season. The analysis is a statistical inference task centered on correlation and, if feasible, lagged regression to test whether meta shifts precede player count changes.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Overwatch 2 launched in October 2022 as a free-to-play title and rapidly built one of the larger hero shooter player bases in the world. The game debuted with roughly 35 million players, and despite moderation through late 2024, still maintains an estimated monthly player base of around 22 million as of early 2025. This scale makes Overwatch 2 a useful subject for studying how game design and competitive health relate to sustained player engagement. https://plg.bet/blog/overwatch-2-player-count/
#
# One of the most persistent complaints in the community concerns "meta staleness," meaning the tendency for only a small handful of heroes to dominate competitive play at any given time. In the 2022 OWL off-season, five heroes had over a 90% pick rate each, while every other hero in the roster sat below 10%. Historically, no off-season meta had seen any single hero exceed an 82% pick rate until that point. This extreme concentration is qualitatively different from the typical strategic metagame found in most competitive titles, and the community widely perceived it as harming the watchability and playability of the game. https://www.afkgaming.com/
#
# The connection between pro-scene meta and casual player behavior is well-documented anecdotally. When a top OWL team ran triple-support compositions in early 2026, support pick rates climbed 3–5% across all ranks within two weeks. Conversely, when Sigma was benched in pro play for two consecutive tournaments, his pick rate dropped nearly 8% in Platinum and Diamond despite no patch changes. This trickle-down effect suggests the pro meta has measurable influence on how the broader player base engages with the game, though no formal statistical study has quantified this relationship over time. Splashworkanimations
# Prior work examining esports and player behavior has primarily focused on health outcomes of gaming rather than game design effects on retention. Kelly and Leung's 2021 scoping meta-review in Frontiers in Sports and Active Living examined 10 reviews of competitive online gaming's health impacts, but noted that the field has focused almost entirely on physical and psychological outcomes rather than game system dynamics and their effect on player populations. No published study we found directly examines whether pro meta diversity predicts player count fluctuations in a live-service game, making this a genuinely novel contribution to the esports research literature. https://splashworkanimations.com/overwatch-pick-rates-explained-the-complete-guide-to-hero-meta-in-2026/
#
# The closest adjacent work examines esports viewership as a proxy for engagement. Esports Charts analysis of Overwatch's competitive viewership found an 88.7% growth in hours watched between the first half of 2022 and the first half of 2023, a period that coincided with the OW2 transition and significant meta shifts. While viewership and player count are not identical, they move together enough to suggest that competitive scene health has downstream effects on the wider community. Our project fills a gap by directly linking the internal structure of the pro meta (pick distribution entropy) to player count rather than using viewership as an intermediary. https://pmc.ncbi.nlm.nih.gov/articles/PMC8008070/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that seasons with higher pro meta diversity (lower hero pick rate concentration) will correlate positively with higher or growing monthly active player counts. Our reasoning is that a diverse meta signals a healthier, more accessible competitive environment, which increases spectator appeal and keeps casual players engaged with a broader pool of viable heroes. We also expect this effect to show a short lag of one to two weeks, as player behavior typically shifts shortly after a major tournament or balance patch rather than instantaneously.

# %% [markdown]
# ## Data

# %% [markdown]
# ## Ideal Dataset
#
# The ideal dataset has two parallel time series aligned by Overwatch 2 season (roughly nine-week intervals):
#
# - Pro meta variable: Hero pick rates across all OWCS matches per season (heroes x matches x tournaments), from which we compute Shannon entropy as a scalar diversity score. Variables needed: hero name, number of picks, total maps played, tournament name, season, date. Ideally at least 30 seasons/sub-seasons of data covering OWL (2018–2023) and OWCS (2023–present), giving roughly 200+ tournament events.
#
# - Player count variable: Monthly active player estimates with at minimum season-level granularity, cross-platform if possible. Variables needed: month, estimated MAU, daily peak concurrents, platform if broken out.
#
# - Control variables: New hero release (binary), major balance patch (binary), season start/end (binary), major external competitive events (e.g., Marvel Rivals launch).Ideally these data are stored in a flat CSV with one row per season-week, allowing time-series regression.
#
#
# ## Real Datasets
# - Winston's Lab (winstonslab.com): Tracks OWL and OWCS hero pick rates by tournament going back to 2017. Data is available via the site's hero statistics pages and some historical exports. This is the primary source for pro meta diversity calculations. Variables include hero, match, map, pick/ban, team, and tournament. Free to access with some scraping required for bulk export.
#
# - Blizzard Official Hero Statistics (overwatch.blizzard.com/en-us/rates): Blizzard's own hero stats page tracks pick rates and win rates for every hero, updated with each patch, across PC, region, and rank tier. This gives ranked/casual pick rate data as a secondary variable. Access is free with no application needed; historical patch-level data requires scraping or community-maintained archives (e.g., OW2 Stats Discord). https://overwatch.blizzard.com/en-us/rates/?input=PC&map=all-maps&region=Americas&role=Support&rq=0&tier=All
#
# - ActivePlayer.io / SteamCharts: Steam player counts average around 25,000 concurrent players with peaks reaching 60,000 during major updates and events, while cross-platform estimates from ActivePlayer capture a broader picture. SteamCharts data is directly accessible via API. ActivePlayer data requires manual collection or web scraping. https://icon-era.com/blog/overwatch-2-live-player-count-and-statistics.77/
#
# The real datasets fall short of the ideal in two ways: (1) Blizzard does not release official cross-platform MAU, so player count estimates remain third-party approximations with unknown error margins; (2) Winston's Lab data pre-OW2 uses a 6v6 format, creating a structural break in the series that requires careful handling or scope limitation to OW2 seasons only.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Our project does not involve human subjects directly. All data comes from publicly available sources: Winston's Lab tournament records, Blizzard's official hero statistics page, and third-party player count aggregators (ActivePlayer.io, SteamCharts). No individual player data or personally identifiable information is collected. Professional players' in-game performance data is publicly broadcast as part of official esports competition, so no consent issues arise.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Our pro meta data comes exclusively from OWCS/OWL tournaments, which represent only the top tier of competitive play and skew toward certain regions (Korea, North America, Europe). Hero picks at the pro level may not reflect broader playerbase behavior. Additionally, our player count data relies on third-party estimators whose methodology is not fully transparent and may systematically over- or undercount certain platforms. We will use SteamCharts as a robustness check and will note these limitations explicitly in our results.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Our dataset contains no PII. We collect hero names, pick counts, tournament names, and aggregated player estimates — none of which are linked to individual player identities. Professional player names may appear in raw scraped data but will not be used in our analysis; we aggregate to the hero/season level only.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > All data is stored in a private GitHub repository accessible only to the five project members. Since no PII or sensitive data is involved, the primary concern is accidental data loss rather than breach. We maintain local backups of all scraped CSVs.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The repository will remain private after project submission. All scraped data is derived from publicly accessible sources, so retention poses no meaningful privacy risk. No data will be redistributed or published beyond the course submission.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > We acknowledge that our analysis reflects the perspective of observers rather than active community members. We have not formally consulted Blizzard, OWCS organizers, or player communities. A key blindspot is that player count changes may be driven by factors (e.g., new hero releases, marketing campaigns) that our model does not fully capture.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We have identified several potential confounders: new hero releases, major balance patches, seasonal events, and external competition (e.g., Marvel Rivals launch). We plan to include these as binary control variables in our regression model. The structural break between 6v6 OWL and 5v5 OW2 formats will be handled by restricting our primary analysis to OW2 seasons only.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will clearly communicate that player count figures are third-party estimates with unknown error margins, not official Blizzard data. All visualizations will include axis labels, confidence intervals where applicable, and explicit notes on data source limitations. We will not overstate the strength of any observed correlation.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > No PII is present in our dataset. All analysis is performed at the hero/season aggregate level.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > All code, data cleaning steps, and analysis will be documented in our Jupyter notebooks with inline comments. The GitHub repository will serve as a complete audit trail. Any team member should be able to rerun the full pipeline from raw scraped data to final figures.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Shannon entropy is our primary diversity metric. We chose it because it is a well-established, interpretable measure of distributional diversity. We will also report the Herfindahl-Hirschman Index (HHI) as an alternative concentration measure to confirm findings are not metric-dependent.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > Our model is a correlation and lagged regression analysis — not a black-box classifier. All coefficients are directly interpretable: a one-unit increase in entropy corresponds to an estimated X-unit change in monthly active players. This is straightforwardly explainable to a non-technical audience.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will include a dedicated limitations section in our final report covering: small sample size (6–8 OW2 seasons), reliance on estimated player counts, inability to establish causation, and the presence of uncontrolled confounders. These will be written in plain language accessible to a general audience.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > The E section items are largely not applicable to this project, as it is an academic analysis and not a deployed system. No automated decisions are made, no users are affected by model outputs, and there is no production environment to monitor or roll back.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# - Communication: Check-ins every week via either a Discord call or an Instagram group chat. Must respond to group chat questions/messages within 24 hours, Monday-Friday.\
#
# - Work quality: If someone writes code, it must be reviewed by at least one other group member. The whole group must agree with merging into the main.
#
# - Conflict resolution: All conflicts must be discussed in the group chat with every member’s input. If there isn't a consensus, members must take a vote, and the majority vote goes.
#
# - Accountability: If a deadline cannot be met, notify the group at least 48 hours in advance.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# |04/27 |  18:00 | Read rubric; finalize research question wording  | Confirm scope, assign background research sections |
# | 04/29 | 20:00 |  Background research complete; identify all data sources | Finalize proposal draft; review ethics section as a group |
# | 04/29 |22:00 | Edit and submit proposal; begin scraping Winston's Lab + SteamCharts  | Review scraping output; troubleshoot data gaps   |
# | 05/08  |17:00  | Data wrangled into clean CSVs; basic EDA complete| Review EDA visualizations; confirm entropy metric approach   |
# | 05/15 | 17:00 | Statistical analysis complete (correlation + lagged regression) | Discuss findings; assign results/discussion writing |
# | 05/27| 17:00  | Draft results and discussion written| Full group review; finalize visualizations |
# | 6/10  | Before 11:59 PM  | Final edits complete| Submit final project and group surveys |
